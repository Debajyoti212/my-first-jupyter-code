# %% [markdown]
# <a href="https://colab.research.google.com/github/Debajyoti212/my-first-jupyter-code/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pandas import read_csv

# %%
import pandas as pd
df=pd.read_csv("Uber Drives 2016 (1).csv")

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(n=12)
# Out:
#         START_DATE*        END_DATE* CATEGORY*           START*  \
# 0    1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1     1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2    1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3    1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4    1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5    1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6    1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7    1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9   1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
# 10  1/10/2016 15:08  1/10/2016 15:51  Business         New York
# 11  1/10/2016 18:18  1/10/2016 18:53  Business         Elmhurst
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# ...

# %%
df.shape
# Out:
# (1156, 7)

# %%
temp = pd.DataFrame({"A":["1","2","3"],"B":[11,12,13],"C": ["12-06-2012","11-06-2015","10-06-2017"]})

# %%
temp
# Out:
#    A   B           C
# 0  1  11  12-06-2012
# 1  2  12  11-06-2015
# 2  3  13  10-06-2017

# %%
temp.shape
# Out:
# (3, 3)

# %%
temp.head()
# Out:
#    A   B           C
# 0  1  11  12-06-2012
# 1  2  12  11-06-2015
# 2  3  13  10-06-2017

# %%
temp.tail()
# Out:
#    A   B           C
# 0  1  11  12-06-2012
# 1  2  12  11-06-2015
# 2  3  13  10-06-2017

# %%
temp.dtypes
# Out:
# A    object
# B     int64
# C    object
# dtype: object

# %%
temp["C"] = pd.to_datetime(temp["C"], dayfirst=True)
print(temp.dtypes)
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %% [markdown]
# #BUILT IN FUNCTION pd.to_datetime

# %%
pd.to_datetime("2016-june-18")
# Out:
# Timestamp('2016-06-18 00:00:00')

# %% [markdown]
# #made an error but dont want to show

# %%
pd.to_datetime(["2025-march-02","abc"],errors="coerce")
# Out:
# <ipython-input-17-9e44b0d998e0>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(["2025-march-02","abc"],errors="coerce")
# DatetimeIndex(['2025-03-02', 'NaT'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# #datas summarization of uber list

# %%
df.describe(include="all")
# Out:
#             START_DATE*        END_DATE* CATEGORY* START* STOP*        MILES*  \
# count              1156             1155      1155   1155  1155   1156.000000
# unique             1155             1154         2    177   188           NaN
# top     6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary           NaN
# freq                  2                2      1078    201   203           NaN
# mean                NaN              NaN       NaN    NaN   NaN     21.115398
# std                 NaN              NaN       NaN    NaN   NaN    359.299007
# min                 NaN              NaN       NaN    NaN   NaN      0.500000
# 25%                 NaN              NaN       NaN    NaN   NaN      2.900000
# 50%                 NaN              NaN       NaN    NaN   NaN      6.000000
# 75%                 NaN              NaN       NaN    NaN   NaN     10.400000
# max                 NaN              NaN       NaN    NaN   NaN  12204.700000
#
#        PURPOSE*
# ...

# %% [markdown]
# #particular column or row

# %%
df["MILES*"].describe()
# Out:
# count     1156.000000
# mean        21.115398
# std        359.299007
# min          0.500000
# 25%          2.900000
# 50%          6.000000
# 75%         10.400000
# max      12204.700000
# Name: MILES*, dtype: float64

# %%
df["START_DATE*"].value_counts()
# Out:
# START_DATE*
# 6/28/2016 23:34    2
# 9/27/2016 13:21    1
# 9/27/2016 8:33     1
# 9/24/2016 20:29    1
# 9/24/2016 14:34    1
#                   ..
# 5/23/2016 20:19    1
# 5/22/2016 18:46    1
# 5/22/2016 15:39    1
# 5/20/2016 15:43    1
# 5/28/2016 12:52    1
# Name: count, Length: 1155, dtype: int64

# %% [markdown]
# #select/indexing

# %%
df.iloc[0:5,0:4]
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce

# %% [markdown]
# #particular columns and rows

# %%
df.iloc[[0,5],[0,3]]
# Out:
#       START_DATE*           START*
# 0  1/1/2016 21:11      Fort Pierce
# 5  1/6/2016 17:15  West Palm Beach

# %% [markdown]
# #label based indexing

# %%
df.loc[:,["START_DATE*","STOP*"]]
# Out:
#            START_DATE*             STOP*
# 0       1/1/2016 21:11       Fort Pierce
# 1        1/2/2016 1:25       Fort Pierce
# 2       1/2/2016 20:25       Fort Pierce
# 3       1/5/2016 17:31       Fort Pierce
# 4       1/6/2016 14:42   West Palm Beach
# ...                ...               ...
# 1151  12/31/2016 13:24  Unknown Location
# 1152  12/31/2016 15:03  Unknown Location
# 1153  12/31/2016 21:32           Gampaha
# 1154  12/31/2016 22:08         Ilukwatta
# 1155            Totals               NaN
#
# [1156 rows x 2 columns]

# %% [markdown]
# #filtering

# %%
df[df["MILES*"]>10]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business          New York
# 23     1/13/2016 13:54   1/13/2016 14:07  Business          Downtown
# ...                ...               ...       ...               ...
# 1134  12/29/2016 11:28  12/29/2016 12:00  Business  Unknown Location
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
df.loc[df["MILES*"]>10,["START_DATE*","START*"]]
# Out:
#            START_DATE*            START*
# 4       1/6/2016 14:42       Fort Pierce
# 9      1/10/2016 12:17           Jamaica
# 10     1/10/2016 15:08          New York
# 22     1/12/2016 16:02          New York
# 23     1/13/2016 13:54          Downtown
# ...                ...               ...
# 1134  12/29/2016 11:28  Unknown Location
# 1144  12/29/2016 23:14  Unknown Location
# 1152  12/31/2016 15:03  Unknown Location
# 1154  12/31/2016 22:08           Gampaha
# 1155            Totals               NaN
#
# [316 rows x 2 columns]

# %% [markdown]
# #FIND ALL THE RIDES FROM NEW YORK

# %%
df1=df.loc[df["START*"]=="New York",["START*","STOP*"]]
df1.head()
# Out:
#        START*             STOP*
# 10   New York            Queens
# 22   New York     Queens County
# 106  New York  Long Island City
# 423  New York           Jamaica

# %% [markdown]
# #STARTING FROM NEWYORK ENDING IN QUEENS

# %%
df.loc[(df["START*"] == "New York") & (df["STOP*"] == "Queens"), ["START*", "STOP*"]]
# Out:
#       START*   STOP*
# 10  New York  Queens

# %% [markdown]
# #STARTING FROM 2 POINTS

# %%
#& is  not used because here and operator is not applicable or is applicable so we used|
df.loc[(df["START*"] == "Cary") | (df["START*"] == "New York")]
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*          STOP*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business      Cary           Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business      Cary    Morrisville
# 10     1/10/2016 15:08   1/10/2016 15:51  Business  New York         Queens
# 22     1/12/2016 16:02   1/12/2016 17:00  Business  New York  Queens County
# 28     1/15/2016 11:43   1/15/2016 12:03  Business      Cary         Durham
# ...                ...               ...       ...       ...            ...
# 1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary           Cary
# 1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary           Cary
# 1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary           Cary
# 1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary    Morrisville
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary    Morrisville
#
#       MILES*        PURPOSE*
# ...

# %%
df.loc[df["START*"].isin(["Cary", "New York"])]
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*          STOP*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business      Cary           Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business      Cary    Morrisville
# 10     1/10/2016 15:08   1/10/2016 15:51  Business  New York         Queens
# 22     1/12/2016 16:02   1/12/2016 17:00  Business  New York  Queens County
# 28     1/15/2016 11:43   1/15/2016 12:03  Business      Cary         Durham
# ...                ...               ...       ...       ...            ...
# 1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary           Cary
# 1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary           Cary
# 1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary           Cary
# 1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary    Morrisville
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary    Morrisville
#
#       MILES*        PURPOSE*
# ...

# %%
import pandas as pd
df=pd.read_csv("Uber Drives 2016 (1).csv")

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.iloc[0:5,:]
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %% [markdown]
# #find all the trips with distance greater than 10 miles and originating from cary and morris

# %%
df.loc[(df["MILES*"]>10 ) & (df["START*"].isin(["cary","Morrisville"]))]
# Out:
#           START_DATE*         END_DATE* CATEGORY*       START*        STOP*  \
# 97    2/12/2016 11:14   2/12/2016 11:35  Business  Morrisville      Raleigh
# 100   2/12/2016 15:33   2/12/2016 16:06  Business  Morrisville         Cary
# 388   5/28/2016 14:35   5/28/2016 15:04  Business  Morrisville         Cary
# 545   7/14/2016 16:03   7/14/2016 16:34  Business  Morrisville  Morrisville
# 546   7/14/2016 16:39   7/14/2016 20:05  Business  Morrisville   Banner Elk
# 587   7/22/2016 15:49   7/22/2016 16:22  Business  Morrisville         Cary
# 604   7/27/2016 21:34   7/27/2016 21:57  Business  Morrisville      Raleigh
# 884  10/31/2016 18:47  10/31/2016 19:16  Business  Morrisville      Raleigh
#
#      MILES*         PURPOSE*
# 97     17.0   Customer Visit
# 100    11.5   Customer Visit
# 388    11.3   Customer Visit
# 545    11.8  Errand/Supplies
# 546   195.3              NaN
# 587    12.2              NaN
# 604    14.7              NaN
# 884    10.3              NaN

# %% [markdown]
# #sorting

# %%
df.sort_values(by=["MILES*"],ascending=True).head(5)
# Out:
#           START_DATE*        END_DATE* CATEGORY*       START*        STOP*  \
# 120   2/17/2016 16:38  2/17/2016 16:43  Business   Katunayaka   Katunayaka
# 420    6/8/2016 17:16   6/8/2016 17:18  Business         Soho      Tribeca
# 44    1/26/2016 17:27  1/26/2016 17:29  Business         Cary         Cary
# 516    7/5/2016 16:48   7/5/2016 16:52  Business  Whitebridge  Whitebridge
# 1111  12/25/2016 0:10  12/25/2016 0:14  Business       Lahore       Lahore
#
#       MILES*         PURPOSE*
# 120      0.5  Errand/Supplies
# 420      0.5  Errand/Supplies
# 44       0.5  Errand/Supplies
# 516      0.6  Errand/Supplies
# 1111     0.6  Errand/Supplies

# %%
df.sort_values(by=["MILES*","START*"],ascending=False)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# ...                ...               ...       ...               ...
# 1121  12/27/2016 12:53  12/27/2016 12:57  Business           Kar?chi
# 945   11/12/2016 13:46  11/12/2016 13:50  Business           Central
# 420     6/8/2016 17:16    6/8/2016 17:18  Business              Soho
# 120    2/17/2016 16:38   2/17/2016 16:43  Business        Katunayaka
# 44     1/26/2016 17:27   1/26/2016 17:29  Business              Cary
#
#                  STOP*   MILES*         PURPOSE*
# 1155               NaN  12204.7              NaN
# ...

# %% [markdown]
# #Conditionally adding columns

# %%
import numpy as np
df["MILES REVIEW*"] = np.where(df["MILES*"] > 10, "long drive", np.where(df["MILES*"] < 10, "short drive", "NaN")) # Replace np.nan with a string "NaN"
                                                                                                                        # or any other string representation for missing value.

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE* MILES REVIEW*
# 0          Fort Pierce      5.1   Meal/Entertain   short drive
# ...

# %% [markdown]
# #shorter

# %%
df["MILES REVIEW*"]=np.where(df["MILES*"]>10,"long drive","short drive")

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE* MILES REVIEW*
# 0          Fort Pierce      5.1   Meal/Entertain   short drive
# ...

# %% [markdown]
# #Create a new column with the following condition:
#
# a) > 10 - Long Trip
#
# b) 5 - 10 - Medium
#
# c) < 5 - Short Trip

# %%
df["MILES REVIEW*"]=np.where(df["MILES*"]>10,"Long Trip",np.where(df["MILES*"]>5,"Medium Trip","Short Trip"))

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE* MILES REVIEW*
# 0          Fort Pierce      5.1   Meal/Entertain   Medium Trip
# ...
